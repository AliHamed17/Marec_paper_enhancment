# %%
import os
import shutil
import sys
import boto3
import json
from io import BytesIO # python2: BytesIO 
import pandas as pd
import logging
import numpy as np
import time
import scipy.stats as ss
from itertools import product
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.pipeline import Pipeline
from scipy import sparse
import pickle
import scipy
import random 
from multiprocessing import Pool
from sklearn.linear_model import LinearRegression, Lasso
from collections import Counter
import matplotlib.pyplot as plt
import bottleneck as bn

from tensorflow.keras.layers import Input, Concatenate, Dense, Dropout, Embedding, Flatten, Dot, MultiHeadAttention, Attention
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L1L2, l1, l2
from tensorflow.keras.callbacks import Callback
import tensorflow as tf

# %% [markdown]
# ### Load training/validation data, hyperparameters, evaluate functions

# %% [markdown]
# Load the pre-processed training and validation data

# %%
#load sparse matrices: sparse matrix of type '<class 'numpy.float64'>
train_data = pickle.loads("<path>-train.pickle")
cold_test_data = pickle.loads("<path>-vad.pickle")
cold_vad_data = pickle.loads("<path>-test.pickle")
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
def NDCG_binary_at_k_batch(X_pred, heldout_batch, k=100):
    '''
    normalized discounted cumulative gain@k for binary relevance
    ASSUMPTIONS: all the 0's in heldout_data indicate 0 relevance
    '''
    batch_users = X_pred.shape[0]
    idx_topk_part = bn.argpartition(-X_pred, k, axis=1)
    topk_part = X_pred[np.arange(batch_users)[:, np.newaxis],
                       idx_topk_part[:, :k]]
    idx_part = np.argsort(-topk_part, axis=1)
    # X_pred[np.arange(batch_users)[:, np.newaxis], idx_topk] is the sorted
    # topk predicted score
    idx_topk = idx_topk_part[np.arange(batch_users)[:, np.newaxis], idx_part]
    # build the discount template
    tp = 1. / np.log2(np.arange(2, k + 2))
#     tp1 = np.ones(len(tp))
    DCG = (heldout_batch[np.arange(batch_users)[:, np.newaxis],
                         idx_topk].toarray() * tp).sum(axis=1)
    
    tp = 1. / np.log2(np.arange(2, k + 2))
#     tp1 =  1. / np.log2(2*np.ones(min(heldout_batch.getnnz(axis=1)),k))
#     IDCG = np.array([tp1.sum() for n in heldout_batch.getnnz(axis=1)])
    IDCG = np.array([(tp[:min(n, k)]).sum() for n in heldout_batch.getnnz(axis=1)])

    return DCG / IDCG


def Recall_at_k_batch(X_pred, heldout_batch, k=100):
    batch_users = X_pred.shape[0]

    idx = bn.argpartition(-X_pred, k, axis=1)
    X_pred_binary = np.zeros_like(X_pred, dtype=bool)
    X_pred_binary[np.arange(batch_users)[:, np.newaxis], idx[:, :k]] = True

    X_true_binary = (heldout_batch > 0).toarray()
    
#     indexes = X_true_binary.sum(axis=1).nonzero()
#     X_pred_binary = X_pred_binary[indexes]
#     X_true_binary = X_true_binary[indexes]

    tmp = (np.logical_and(X_true_binary, X_pred_binary).sum(axis=1)).astype(np.float32)
#     recall = tmp / X_true_binary.sum(axis=1)
    recall = tmp / np.minimum(k, X_true_binary.sum(axis=1))
    return recall

# %% [markdown]
# ### Compute metadata features

# %%
def get_movieId_from_indexes(idx, unique_id_list):
    return unique_id_list[idx]

# %%
unique_id_csv = pd.read_csv('s3://jul-atv/Netflix/pro_sg/unique_sid_netflix.csv', header=None)
unique_id_list = unique_id_csv[unique_id_csv.columns[0]].to_numpy()

# %%
json_content = json.loads("<path>-netflix-metadata.json")
# Out:
# array([    1,     3,     6, ..., 17764, 17769, 17770])

# %%
list_genres = []
list_actors = []
list_directors = []
list_producers = []
list_composers = []

list_year = []
list_runtime = []
list_adult = []

vocabulary_title = []

# %%
def cosine_sim(encoding,shrinkage=0.1):
    sim1 = encoding.dot(encoding.T)
    norm_fi = np.linalg.norm(encoding,axis=1)
    sim2 = np.outer(norm_fi,norm_fi)+shrinkage
    sim = sim1/sim2
    return sim

# %%
# we need to create the IxI similarity matrices with the same indices the UxI matrix is constructed 
counter = 0
# create similarity matrices now, same indexing as sparse UxI click matrix 
for key in json_content: 
    
    data = json_content[key]['title'] 
    vocabulary_title.extend(data.split())

    list_actors.extend(json_content[key]['actors'])
    list_actors.extend(json_content[key]['actresses'])
    list_directors.extend(json_content[key]['directors']) 
    list_composers.extend(json_content[key]['composers']) 
    list_producers.extend(json_content[key]['producers']) 
    list_genres.extend(json_content[key]['genre'])
    
    counter += 1

set_actors = set(list_actors)
set_directors = set(list_directors)
set_genres = set(list_genres)
set_vocabulary_title = set(vocabulary_title)

corpus_title = [json_content[key]['title'] for key in json_content]
corpus_actors = [list(set(json_content[key]['actors']+json_content[key]['actresses'])) for key in json_content]
corpus_composers= [json_content[key]['composers'] for key in json_content]
corpus_producers= [json_content[key]['producers'] for key in json_content]
corpus_directors = [json_content[key]['directors'] for key in json_content]
corpus_genres = [json_content[key]['genre'] for key in json_content]

counter_actors = Counter(list_actors)
df_actors = pd.DataFrame(list(counter_actors.items()),columns = ['actors','count'])
df_actors = df_actors.sort_values("count",ascending=False)
# max_features = len(df_actors)//5
df_actors= df_actors[df_actors["count"]>=2]
# df_actors = df_actors.iloc[:max_features]
print(len(df_actors))

counter_directors = Counter(list_directors)
df_directors = pd.DataFrame(list(counter_directors.items()),columns = ['directors','count'])
df_directors = df_directors.sort_values("count",ascending=False)
df_directors= df_directors[df_directors["count"]>=2]
print(len(df_directors))

counter_producers = Counter(list_producers)
df_producers = pd.DataFrame(list(counter_producers.items()),columns = ['producers','count'])
df_producers = df_producers.sort_values("count",ascending=False)
df_producers= df_producers[df_producers["count"]>=2]
print(len(df_producers))

counter_composers = Counter(list_composers)
df_composers = pd.DataFrame(list(counter_composers.items()),columns = ['composers','count'])
df_composers = df_composers.sort_values("count",ascending=False)
df_composers = df_composers[df_composers["count"]>=2]
print(len(df_composers))


max_features = 1000
pipe_title = Pipeline([('count', CountVectorizer(stop_words='english',max_features=max_features))]).fit(corpus_title)
data_title = pipe_title.transform(corpus_title).toarray()

# should use transformer embeddings instead
# data_title = np.load('title.npy')
# data_title = pickle.loads(s3.Bucket("toby-visual-recommender").Object("ML10M/LLM/title_emb.pickle").get()['Body'].read())


# pipe_description = Pipeline([('count', CountVectorizer(stop_words='english',max_features=max_features))]).fit(corpus_description)
# data_description = pipe_description.transform(corpus_description).toarray()
# # should use transformer embeddings instead
# data_description = np.load('description.npy')
# data_description = pickle.loads(s3.Bucket("toby-visual-recommender").Object("ML10M/LLM/description_emb.pickle").get()['Body'].read())


mlb = MultiLabelBinarizer(classes = list(df_actors.actors))
# mlb = MultiLabelBinarizer()
encoding_actors = mlb.fit_transform(corpus_actors)

mlb = MultiLabelBinarizer(classes = list(df_directors.directors))
# mlb = MultiLabelBinarizer()
encoding_directors = mlb.fit_transform(corpus_directors)

mlb = MultiLabelBinarizer(classes = list(df_composers.composers))
# mlb = MultiLabelBinarizer()
encoding_composers = mlb.fit_transform(corpus_composers)

mlb = MultiLabelBinarizer(classes = list(df_producers.producers))
# mlb = MultiLabelBinarizer()
encoding_producers = mlb.fit_transform(corpus_producers)

mlb = MultiLabelBinarizer()
encoding_genres = mlb.fit_transform(corpus_genres)
# Out:
# 5352
# 1604
# 1818
# 923
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/preprocessing/_label.py:861: UserWarning: unknown class(es) ["'Weird Al' Yankovic", 'A Martinez', 'A. Day Henden', 'A. Lukin', 'A. Scott', 'A.J. Benza', 'A.J. Bond', 'A.J. Buckley', 'A.J. McLean', 'A.K. Hangal', 'Aakash Pandey', 'Aaliyah', 'Aaref Rodriguez', 'Aaron Hildebrand', 'Aaron Jenkins', 'Aaron Joseph', 'Aaron Krohn', 'Aaron Lohr', 'Aaron Long', 'Aaron Paul', 'Aaron Ruell', 'Aaron Schwartz', 'Aaron Sims', 'Aaron Stanford', 'Aaron Taylor-Johnson', 'Aaron Williams', 'Aaryn Doyle', 'Aashish Chaudhary', 'Aasif Mandvi', 'Abba Eban', 'Abbie Acevedo', 'Abdalla Mahmoud', 'Abdelhak Zhayra', 'Abderrahim Daris', 'Abdolhosein Bagheri', 'Abe Vigoda', 'Abhay Chopra', 'Abhay Deol', 'Abigail Breslin', 'Abigail Cruttenden', 'Abraham Alvarez', 'Ace Bhatti', 'Achala Sachdev', 'Ada Choi', 'Adam Ant', 'Adam Bryant', 'Adam Cheng', 'Adam Cockburn', 'Adam Cox', 'Adam Farrar', 'Adam Fidusiewicz', 'Adam Greer', 'Adam Hann-Byrd', 'Adam Henderson', 'Adam Jones', 'Adam Kaufman', 'Adam LaVorgna', 'Adam Monty', 'Adam Nagata', 'Adam Nathan', 'Adam Pawlikowski', 'Adam Peltzman', 'Adam Scott', 'Adam Smoluk', 'Adam T. Dawson', 'Adam Tuominen', 'Adam West', 'Adam Williams', 'Adam Woolf', 'Adam Woronowicz', 'Adamo Palladino', 'Adele Mara', 'Adele Schmidt', 'Adilah Barnes', 'Aditya Srivastav', 'Adolph Caesar', 'Adria Dawn', 'Adrian Bower', 'Adrian Brine', 'Adrian Hoven', 'Adrian Martinez', 'Adrian Pasdar', 'Adrian Rawlins', 'Adrian Walton', 'Adrian Zmed', 'Adriana Alexander', 'Adriano Giannini', 'Adrien Aumont', 'Adrien Dorval', 'Adrien de Van', 'Adrienne Clune', 'Adrienne Corri', 'Adrienne Houghton', 'Adrienne King', 'Adrienne Servantie', 'Adrián Gordillo', 'Afshin Khorshid Bakhtiari', 'Agathe Teyssier', 'Agelem Habibi', 'Agga Olsen', 'Agnes Bruckner', 'Agnes Oaks', 'Agnieszka Wagner', 'Agostina Belli', 'Ah-Lei Gua', 'Ah-Niu', 'Ahmad Jamal McGhee', 'Ahmad Riaz', 'Ahn Nae-sang', 'Ahna Capri', 'Ai Kobayashi', 'Ai Maeda', 'Ai Satô', 'Ai Uchikawa', 'Ai Wan', 'Ai Yamamoto', 'Aidan Fraser', 'Aidan Gillen', 'Aidan Tierney', 'Aidee Walker', 'Aimee Garcia', 'Ajay Naidu', 'Ajmal', 'Akbar Kurtha', 'Akbar Moazezi', 'Akemi Negishi', 'Akemi Yamaguchi', 'Akeno Junko', 'Akhilendra Mishra', 'Aki Avni', 'Aki Maeda', 'Akiko Morison', 'Akiko Wakabayashi', 'Akiko Yajima', 'Akio Kobori', 'Akira Emoto', 'Akira Fujita', 'Akira Ishihama', 'Akira Takarada', 'Akira Takayama', 'Akira Terao', 'Akira Yamanouchi', 'Al Abrams', 'Al Bernstein', 'Al Cliver', 'Al Franken', 'Al Freeman Jr.', 'Al Giordano', 'Al Harrington', 'Al Lettieri', 'Al Shannon', 'Al Thompson', 'Al Waxman', 'Alain Aswani', 'Alain Bashung', 'Alain Benatar', 'Alain Chabat', 'Alain Cuny', 'Alain Dion', 'Alain Libolt', 'Alain Soral', 'Alakina Mann', 'Alan Abelew', 'Alan Austin', 'Alan Bennett', 'Alan Boyce', 'Alan Bunce', 'Alan Committie', 'Alan Cox', 'Alan Davies', 'Alan Devlin', 'Alan Dexter', 'Alan Dinehart', 'Alan Fawcett', 'Alan Ford', 'Alan Gelfant', 'Alan Gryfe', 'Alan Hale Jr.', 'Alan Hobson', 'Alan Howard', 'Alan McKenna', 'Alan North', 'Alan Ormsby', 'Alan Rachins', 'Alan Roberts', 'Alan Roscoe', 'Alan Rosenberg', 'Alan Ruck', 'Alan Scarfe', 'Alan Scott', 'Alan Thicke', 'Alan Van Sprang', 'Alan Webb', 'Alan Weeks', 'Alana Stewart', 'Alastair Galbraith', 'Albert Austin', 'Albert Chung', 'Albert Dupontel', 'Albert Hall', 'Albert Henderson', 'Albert Precourt', 'Albert Préjean', 'Albert Sharpe', 'Alberta Cifolelli', 'Alberto Colombatto', 'Alberto Cucca', 'Alberto Morin', 'Alberto Sordi', 'Alberto de Mendoza', 'Alden Crews', 'Aldo Fabrizi', 'Aldo Massasso', 'Alec Cawthorne', 'Alec McCowen', 'Alec Medlock', 'Aleisha Allen', 'Alejandra Gutierrez', 'Alejandro Rey', 'Alejandro Urdapilleta', 'Aleka Katselli', 'Aleksa Palladino', 'Aleksander Bardini', 'Aleksandr Antonov', 'Aleksandr Baluev', 'Aleksandr Chistyakov', 'Aleksandr Fatyushin', 'Aleksandr Kalyagin', 'Aleksandr Kuznetsov', 'Aleksandr Razbash', 'Aleksei Neymyshev', 'Aleksei Smirnov', 'A ...
#   .format(sorted(unknown, key=str)))
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/preprocessing/_label.py:861: UserWarning: unknown class(es) ['A. Dean Bell', 'A.W. Vidmer', 'Aaron Lubarsky', 'Aaron Norris', 'Abdul Malik Abbott', 'Abe Levitow', 'Abraham Polonsky', 'Abrar Alvi', 'Ace Cruz', 'Achim von Borries', 'Adam Abraham', 'Adam Arkin', 'Adam Brooks', 'Adam Collis', 'Adam Elliot', 'Adam Grossman', 'Adam Larson Broder', 'Adam McKay', 'Adam Park', 'Adam Resnick', 'Adam Ripp', 'Adam Sherman', 'Adam Wong', 'Adolfo Aristarain', 'Adolfo Doring', 'Adrian Scartascini', 'Adrian Shergold', 'Adrienne Shelly', 'Ahathian', 'Aisling Walsh', 'Aiyana Elliott', 'Aki Kaurismäki', 'Akihiko Shiota', 'Akinobu Ishiyama', 'Akiyuki Shinbô', 'Al Adamson', 'Al Corley', 'Al Reinert', 'Alain Berliner', 'Alain Jakubowicz', 'Alan Arkin', 'Alan Brown', 'Alan Cohn', 'Alan Gibson', 'Alan Grint', 'Alan Holleb', 'Alan J. Kelly', 'Alan Lewens', 'Alan Mak', 'Alan Metzger', 'Alan Rafkin', 'Alan Raymond', 'Alan Rickman', 'Alan Roberts', 'Alan Smithee', 'Alan Vint', 'Alan Wade', 'Alan White', 'Albert Lewin', 'Albert Magnoli', 'Albert Maysles', 'Albert Parker', 'Alberto Lattuada', 'Alberto Sciamma', 'Alejandro Sessa', 'Aleksandr Seryy', 'Aleksandr Zarkhi', 'Aleksey Balabanov', 'Aleksi Salmenperä', 'Alex Chandon', 'Alex Jamison', 'Alex Mebane', 'Alex Munoz', 'Alex Pillai', 'Alex Sichel', 'Alex Smith', 'Alex Weinress', 'Alex Wright', 'Alex Zamm', 'Alexander Finbow', 'Alexander Marengo', 'Alexander Witt', 'Alexandra Pelosi', 'Alfonso Pineda Ulloa', 'Alfred Zeisler', 'Alfredo Ramos', 'Alfredo Rodriguez de Villa', 'Alice Wilder', 'Allan Albert', 'Allan Burns', 'Allen Nause', 'Allen Reisner', 'Alyson Smith', 'Aman Chang', 'Amir Mann', 'Amol Palekar', 'Amos Kollek', 'Amy Schatz', 'Amy Stechler', 'Amy Ziering', 'Ana Clavell', 'Anand Tucker', 'Anant Balani', 'Anatole Litvak', 'Andaleeb Sultanpuri', 'Anders Rønnow Klarlund', 'Anders Thomas Jensen', 'Andre Braugher', 'Andrea Ambandos', 'Andrea Meyerson', 'Andrei Svislotski', 'Andrew Adamson', 'Andrew Black', 'Andrew Dominik', 'Andrew Douglas', 'Andrew Gallerani', 'Andrew Green', 'Andrew Gurland', 'Andrew Horn', 'Andrew J. Kuehn', 'Andrew J. Smith', 'Andrew Jarecki', 'Andrew Mollo', 'Andrew Morahan', 'Andrew Niccol', 'Andrew Piddington', 'Andrew Scheinman', 'Andrew Shea', 'Andrew Sipes', 'Andrew Stanton', 'Andrew Stevens', 'Andrew Sugerman', 'Andrew Theopolis', 'Andrey Zvyagintsev', 'Andrucha Waddington', 'André Bonzel', 'André De Toth', 'Andy Cadiff', 'Andy Orjuela', 'Andy Wilson', 'Angela Christlieb', 'Angela Evers Hughey', 'Angela Pope', 'Angela Robinson', 'Ani Thomas', 'Anil Ganguly', 'Anna Campion', 'Anna Maria Tatò', 'Anne Belle', 'Anne Fontaine', 'Anne Heche', 'Anne Misawa', 'Anne-Sophie Birot', 'Annette Haywood-Carter', 'Annick Vroom', 'Anthony Abrams', 'Anthony Doublin', 'Anthony Howard', 'Anthony Kimmins', 'Anthony M. Bongiovi', 'Anthony Page', 'Anthony Russo', 'Anthony Van Laast', 'Antoine de Caunes', 'Antonio Banderas', 'Antonio Capuano', 'Antonio Cuadri', 'Antonio Hernández', 'Antonio Margheriti', 'Antony Balch', 'Antony Hoffman', 'Aparna Sen', 'Arik Kaplun', 'Arild Andresen', 'Arjun Sablok', 'Arlene Nelson', 'Arlene Sanford', 'Arliss Howard', 'Arna Selznick', 'Arnaud Desplechin', 'Arnold Levine', 'Arnold Schwarzenegger', 'Arnold Shapiro', 'Art Linson', 'Arthur Bradford', 'Arthur Crabtree', 'Arthur H. Nadel', 'Arthur Hilton', 'Arthur Ripley', 'Arthur Rosson', 'Ash Brannon', 'Ashton Root', 'Ashutosh Gowariker', 'Ate de Jong', 'Attila Bertalan', 'Aubrey Powell', 'Avi Nesher', 'Aviva Kempner', 'Babak Payami', 'Bahman Ghobadi', 'Baltasar Kormákur', 'Barbara Hammer', 'Barbara Leibovitz', 'Barbara Peeters', 'Barnet Kellman', 'Barrie Nelson', 'Barry L. Young', "Barry O'Riordan", 'Barry Poltermann', 'Barry Shear', 'Barry Skolnick', 'Basu Chatterjee', 'Beau Lambert', 'Ben Hecht', 'Ben Ramsey', 'Ben Sombogaart', 'Ben Younger', 'Benito Zambrano', 'Benjamin Ross', 'Benni Diez', 'Benoît Jacquot', 'Berit Nesheim', 'Bernard Dey ...
#   .format(sorted(unknown, key=str)))
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/preprocessing/_label.py:861: UserWarning: unknown class(es) ['AC/DC', 'Aaron Davis', 'Abdullah Ibrahim', 'Abe Meyer', 'Acrobat', 'Adam Cohen', 'Adam Dorn', 'Adam F.', 'Adam Gorgoni', 'Adam Hamilton', 'Adam Jeremy Williams', 'Adam Nordén', 'Adam Nowak', 'Adam Peters', 'Adam Plack', 'Adolph Hallis', 'Adrian Lee', 'Afrika', 'Ahmad Pezhman', 'Ahrin Mishan', 'Aimee-Lynn Chadwick', 'Akihiko Matsumoto', 'Akis Daoutis', 'Alain Jomy', 'Alain Romans', 'Alan Ari Lazar', 'Alan Elliott', 'Alan John', 'Alan Koshiyama', 'Alan Lisk', 'Alan Menken', 'Alan Moore', 'Alan Pasqua', 'Alan Williams', 'Alastair King', 'Albert Sendrey', 'Albert Zabel', 'Alberto Baldan Bembo', 'Alberto Caruso', 'Alberto Delgado', 'Aldo De Scalzi', 'Alejandro Marcovich', 'Alejandro Massó', 'Aleksandar Habic', 'Ales Brezina', 'Alessandro Molinari', 'Alex Beaupain', 'Alex Gibson', 'Alex Parker', 'Alex Pauk', 'Alex Proyas', 'Alexander Courage', 'Alexander Faris', 'Alexander Hacke', 'Alexander Janko', 'Alexander Peskanov', 'Alexina Louie', 'Alf Clausen', 'Alfonso de Vilallonga', 'Alison Gordy', 'Allan Gray', 'Allen Cato', 'Allen Lynch', 'Allen Shawn', 'Allison Hennessy', 'Alto Reed', 'Amedeo Tommasi', 'Amir Moini', 'Amit Heri', 'Amy Domingues', 'Amy Marie Beauchamp', 'Amy Odell', 'Anders Berglund', 'Andre Douglas', 'Andre Fratto', 'Andrea Guerra', 'Andrea Saparoff', 'Andreas Geck', 'Andreas Kersting', 'Andreas Mattsson', 'Andres Gerszenzon', 'Andrew Belling', 'Andrew Feltenstein', 'Andrew Lancaster', 'Andrew Lockington', 'Andrew Michael King', 'Andrew Phillips', 'Andrew Powell', 'Andrew Sutherland', 'Andrew Tuason', 'Andrew Warboys', 'Andrew Williams', 'Andrew Worboys', 'Andrey Dergachev', 'Andrey Petrov', 'Andrey Sigle', 'Andrzej Markowski', 'André Dziezuk', 'André Hossein', 'Andrés Goldstein', 'Andy Cheung', 'Andy Paley', 'Andy Price', 'Anette Skrzydlo', 'Angelo Francesco Lavagnino', 'Anjan Biswas', 'Anthony Collins', 'Anthony Grimaldi', 'Anthrax', 'Antonio Carlos Jobim', 'Antonio Coppola', 'Antonio Cora', 'Antonio Marangolo', 'Antonio Meliveo', 'Antony Partos', 'Arban Ornelas', 'Arlan H. Boll', 'Arlene Barnett', 'Arlon Ober', 'Armand Amar', 'Armand Bernard', 'Armando Trovajoli', 'Arnold Bax', 'Arsalan Kamkar', 'Arthur Kay', 'Arthur Lange', 'Arthur Wright', 'Artie Butler', 'Arturo Blasco', 'Asche & Spencer', 'Askold Buk', 'Atilio Stampone', 'Atli Örvarsson', 'Atorie Shira', 'Axel Krygier', 'B. Quincy Griffin', 'Babak Bayat', 'Babloo Chakravorty', 'Bad Livers', 'Ball of Waxx', 'Balázs Barna', 'Banda Osiris', 'Bappi Lahiri', 'Barb Morrison', 'Barrie Guard', 'Barron Abramovitch', 'Barry Coffing', 'Barry Gibb', 'Barry Manilow', 'Barry Taylor', 'Bashar Abd Rabbou', 'Basil Kirchin', 'Bee And Flower', 'Ben Blossner', 'Ben Carson', 'Ben Cheung', 'Ben Goldberg', 'Ben Mink', 'Ben Vaughn', 'Ben Watkins', 'Ben Wittman', 'Bence Kutrik', 'Benjamin Newhouse', 'Bennie Wallace', 'Benny Carter', 'Benoit Jutras', 'Benoît Charest', 'Bent Fabricius-Bjerre', 'Beo Morales', 'Berington Van Campen', 'Bernard Kawka', 'Bernardo Fuster', 'Bernd Schultheis', 'Bert Shefter', 'Betty E. Box', 'Bhavatharini', 'Bill Brown', 'Bill Elliott', 'Bill Justis', 'Bill Lacey', 'Bill Meyers', 'Bill Rogers', 'Bill Stafford', 'Bill Toles', 'Bill Wandel', 'Billy Barnes', 'Billy Bragg', 'Billy Corgan', 'Billy May', 'Billy Sherrill', 'Billy Straus', 'Björn Isfält', 'Blake Neely', 'Blind Faith', 'Blue Weaver', 'Bo Holten', 'Bob Alcivar', 'Bob Brozman', 'Bob Christianson', 'Bob Davis', 'Bob Durham', 'Bob Esty', 'Bob Geldof', 'Bob Gilligan', 'Bob Steward', 'Bob Telson', 'Bob Zimmerman', 'Bobby McFerrin', 'Bobby Previte', 'Bobby Scott', 'Bon Wong', 'Boo Hewerdine', 'Boris Blank', 'Boris Elkis', 'Boxhead Ensemble', 'Brad Chiet', 'Brad Segal', 'Brad Wilk', 'Bradley Smith', 'Brantley Kearns', 'Brendan Dolan', 'Brent Barkman', 'Brent Michael Davids', 'Brian Balmages', 'Brian Bell', 'Brian Benison', 'Brian D. Horrorwitz', 'Brian Gascoigne', 'Brian  ...
#   .format(sorted(unknown, key=str)))
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/preprocessing/_label.py:861: UserWarning: unknown class(es) ['A.C. Lyles', 'A.G. Nadiadwala', 'A.M. Rathnam', 'Aadi Sheshagiri Rao Ghattamaneni', 'Aaron Merrell', 'Aaron Weinstein', 'Abe Schneider', 'Ace Norton', 'Achille Manzotti', 'Achille Piazzi', 'Adam Berns', 'Adam Bohling', 'Adam Clapham', 'Adam Del Deo', 'Adam Doench', 'Adam Kline', 'Adam Koebel', 'Adam Sandler', 'Adam Shapiro', 'Adam Singer', 'Aditya Chopra', 'Adrian Belic', 'Adrian Scott', 'Agatha Dominik', 'Agi Orsi', 'Agnès Le Pont', 'Ailsa Orr', 'Aimée Danis', 'Ajay Tuli', 'Ajit Kumar Barjatya', 'Akifumi Takuma', 'Akiko Funatsu', 'Akiva Goldsman', 'Al Croft', 'Al Klingenstein', 'Al Lichtman', 'Al Masocco', 'Al Ruban', 'Alain Belmondo', 'Alain Demeestere', 'Alain Depardieu', 'Alain Redaelli', 'Alain Rozanès', 'Alain Silver', 'Alain Siritzky', 'Alain Terzian', 'Alain Tortevoix', 'Alan Barnette', 'Alan Belkin', 'Alan E. Salke', 'Alan Horrox', 'Alan J. Wands', 'Alan Kleinberg', 'Alan Levin', 'Alan Moloney', 'Alan Padula', 'Alan Ravenscroft', 'Alan Shallcross', 'Alana H. Lambros', 'Alastair Laurence', 'Albert Pyun', 'Albert T. Dickerson III', 'Alec Lorimore', 'Alejandro Belloti', 'Alejandro Sessa', 'Aleksi Bardy', 'Alessandro Jacchia', 'Alessandro Sforza', 'Alex Gibney', 'Alex Gottlieb', 'Alex Hyde-White', 'Alex Rockwell', 'Alex Siskin', 'Alexander Chan', 'Alexander R. Stigler', 'Alexander Salkind', 'Alexander Thies', 'Alexandra Juhasz', 'Alexandra Raffe', 'Alexia Cirino', 'Alfonso Cuarón', 'Alfred Haber', 'Alfred Levy', 'Alfredo Bini', 'Alfredo Leone', 'Alfredo Mirabile', 'Alfredo Ripstein Jr.', 'Ali Ghaemmaghami', 'Ali LeRoi', 'Ali Pomeroy', 'Alicia Allain', 'Alison Dickey', 'Alison Gilby', 'Alison R. Rosenzweig', 'Allan L. Durand', 'Allan Marcil', 'Allan Miller', 'Allan Mindel', 'Allen Bain', 'Allen Klein', 'Allen Newman', 'Allen Shapiro', 'Allison R. Hebble', 'Allu Aravind', 'Aluri Chakrapani', 'Aly Morani', 'Amalia Mato', 'Amanda Marmot', 'Amanda Micallef', 'Amanda Posey', 'Ameake Owens', 'Amedeo Pagani', 'Amedeo Ursini', 'Amy Bolton-Curley', 'Amy Greenspun', 'Amy Heckerling', 'Amy J. Moore', 'Amy J. Russell', 'Amy Krell', 'Amândio Coroado', 'Anand Tucker', 'Anastasia Sideris', 'Anastasios Vasiliou', 'Anat Bikel', 'Anaye Milligan', 'Andre Harrell', 'Andre Lamal', 'Andrea Barata Ribeiro', 'Andrea Calderwood', 'Andrea Dray', 'Andrea Schroder', 'Andreas Grosch', 'Andreas Hess', 'Andrew Bonime', 'Andrew Brown', 'Andrew Fogelson', 'Andrew G. La Marca', 'Andrew Gernhard', 'Andrew Hersh', 'Andrew J. Kuehn', 'Andrew L. Moore', 'Andrew Lau', 'Andrew Lipson', 'Andrew Lloyd Webber', 'Andrew Loo', 'Andrew MacNaughtan', 'Andrew McPhail', 'Andrew Shack', 'Andrew Spaulding', 'Andrew Steuart', 'Andrew Sugerman', 'Andrew W. Garroni', 'Andrew Wald', 'Andrew Z. Davis', 'Andrey Deryabin', 'Andrzej Kamrowski', 'András Böhm', 'André Hakim', 'André Link', 'André Michelin', 'André Paquette', 'André Rouleau', 'André Samarcq', 'Andrée Molyneux', 'Andrés Santana', 'Andy Heyward', 'Andy Howard', 'Angela Roessel', 'Angelo Barbagallo', 'Angi Bones', 'Angus Lamont', 'Anis Nohra', 'Anita Lee', 'Anita Luckett', 'Anjalika Mathur Nigam', 'Ann Wingate', 'Anna B. Pizarro', 'Anna J. Devlin', 'Anna Stratton', 'Anne Carey', 'Anne François', 'Anne Harrison', 'Anne Kimmel', 'Anne Kurtzman', 'Anne Lordon', 'Anne Masson', 'Anne Pivcevic', 'Anne Wood', 'Anne-Dominique Toussaint', 'Anne-Marie Casey', 'Anne-Marie Mackay', 'Annette Handley Chandler', 'Annette Pisacane', 'Annette Vait', 'Anoop Sharma', 'Anouk Fontaine', 'Anshuman Swami', 'Anthony B. Unger', 'Anthony Bennett', 'Anthony Vozza', 'Anthony Wall', 'Antoine Voituriez', 'Anton Smit', 'Antonio Crescenzi', 'Antonio P. Pérez', 'Antony I. Ginnane', 'António da Cunha Telles', 'April White', 'Ara Katz', 'Arash Ayrom', 'Ari Newman', 'Ari Palitz', 'Ariane Krampe', 'Ariane Moody', 'Aristides McGarry', 'Arne Glimcher', 'Arnie Gelbart', 'Arnold Messer', 'Aron Warner', 'Arthur Goldblat ...
#   .format(sorted(unknown, key=str)))

# %%
Btitle = np.array(data_title)
Bgenres = encoding_genres
Bactors = np.array(encoding_actors)
Bdirectors = np.array(encoding_directors)
Bproducers = np.array(encoding_producers)
Bcomposers = np.array(encoding_composers)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

Bgenres = scaler.fit_transform(Bgenres)
Bactors = scaler.fit_transform(Bactors)
Bdirectors = scaler.fit_transform(Bdirectors)
Bcomposers = scaler.fit_transform(Bcomposers)
Bproducers = scaler.fit_transform(Bproducers)
Btitle = scaler.fit_transform(Btitle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e2e718d2bba> in <module>
#       2 scaler = MinMaxScaler()
#       3
# ----> 4 Bgenres = scaler.fit_transform(Bgenres)
#       5 Bactors = scaler.fit_transform(Bactors)
#       6 Bdirectors = scaler.fit_transform(Bdirectors)
#
# NameError: name 'Bgenres' is not defined

# %%
def cosine_sim(encoding,shrinkage=0.1):
    sim1 = encoding.dot(encoding.T)
    norm_fi = np.linalg.norm(encoding,axis=1)
    sim2 = np.outer(norm_fi,norm_fi)+shrinkage
    sim = sim1/sim2
    return sim

# %%
B1 = cosine_sim(Btitle, shrinkage=50)
B2 = cosine_sim(Bactors, shrinkage=50)
B3 = cosine_sim(Bdirectors, shrinkage=50)
B4 = cosine_sim(Bproducers, shrinkage=50)
B5 = cosine_sim(Bcomposers, shrinkage=50)
B6 = cosine_sim(Bgenres, shrinkage=50)

# %%
size = B1.shape[0]
for i in range(size):
    B1[i,i]=0
    B2[i,i]=0
    B3[i,i]=0
    B4[i,i]=0     
    B5[i,i]=0
    B6[i,i]=0

# %% [markdown]
# ## baseline sum of cosine similarities

# %%
B12 = B1*B2
B13 = B1*B3
B14 = B1*B4
B15 = B1*B5
B23 = B2*B3
B24 = B2*B4
B25 = B2*B5
B34 = B3*B4
B35 = B3*B5
B45 = B4*B5

# %%
X = train_data.toarray()
X1 = X.dot(B1)
X2 = X.dot(B2)
X3 = X.dot(B3)
X4 = X.dot(B4)
X5 = X.dot(B5)
X6 = X.dot(B6)
X12 = X.dot(B12)
X13 = X.dot(B13)
X14 = X.dot(B14)
X15 = X.dot(B15)
X23 = X.dot(B23)
X24 = X.dot(B24)
X25 = X.dot(B25)
X34 = X.dot(B34)
X35 = X.dot(B35)
X45 = X.dot(B45)

print("X^{(i)} computed")
# del B1, B2, B3, B4, B5, json_content

X = np.asarray(X).reshape((X.shape[0]*X.shape[1],1))
Xtot = np.concatenate((np.asarray(X1).reshape((X1.shape[0]*X1.shape[1],1)),
                      np.asarray(X2).reshape((X2.shape[0]*X2.shape[1],1)),
                       np.asarray(X3).reshape((X3.shape[0]*X3.shape[1],1)),
                      np.asarray(X4).reshape((X4.shape[0]*X4.shape[1],1)),
                       np.asarray(X5).reshape((X5.shape[0]*X5.shape[1],1)),
                      np.asarray(X12).reshape((X12.shape[0]*X12.shape[1],1)),
                       np.asarray(X13).reshape((X13.shape[0]*X13.shape[1],1)),
                      np.asarray(X14).reshape((X14.shape[0]*X14.shape[1],1)),
                       np.asarray(X15).reshape((X15.shape[0]*X15.shape[1],1)),
                      np.asarray(X23).reshape((X23.shape[0]*X23.shape[1],1)),
                       np.asarray(X24).reshape((X24.shape[0]*X24.shape[1],1)),
                      np.asarray(X25).reshape((X25.shape[0]*X25.shape[1],1)),
                       np.asarray(X34).reshape((X34.shape[0]*X34.shape[1],1)),
                       np.asarray(X35).reshape((X35.shape[0]*X35.shape[1],1)),
                       np.asarray(X45).reshape((X45.shape[0]*X45.shape[1],1))),axis=1)

my_array = X.copy()
my_array[my_array == 0] = 0.1
my_array = my_array.flatten()


reg = LinearRegression(positive=True).fit(Xtot, X, sample_weight=my_array)

print("linear regression fitted")

# %%
reg.coef_

# %%
X1bis = reg.coef_[0][0]*X1
X2bis = reg.coef_[0][1]*X2
X3bis = reg.coef_[0][2]*X3
X4bis = reg.coef_[0][3]*X4
X5bis = reg.coef_[0][4]*X5
X6bis = reg.coef_[0][5]*X6

X6bis = reg.coef_[0][6]*X12
X7bis = reg.coef_[0][7]*X13
X8bis = reg.coef_[0][8]*X14
X9bis = reg.coef_[0][9]*X15
X10bis = reg.coef_[0][10]*X23
X11bis = reg.coef_[0][11]*X24
X12bis = reg.coef_[0][12]*X25
X13bis = reg.coef_[0][13]*X34
X14bis = reg.coef_[0][14]*X35
X15bis = reg.coef_[0][15]*X45
X16bis = reg.coef_[0][16]*X45

pred_val = X1bis+X2bis+X3bis+X4bis+X5bis+X6bis+X7bis+X8bis+X9bis+X10bis+X11bis+X12bis+X13bis+X14bis+X15bis+X16bis
values = train_data.nonzero()
pred_val[values] =  -np.inf

# %%
del X1, X2, X3, X4, X5

# %%
n10_list, r10_list, n25_list, r25_list, n50_list, r50_list, n100_list, r100_list = [], [],[], [],[], [],[], []
r10_list.append(Recall_at_k_batch(pred_val,cold_test_data, k=10))
n10_list.append(NDCG_binary_at_k_batch(pred_val,cold_test_data, k=10))
r25_list.append(Recall_at_k_batch(pred_val, cold_test_data, k=25))
n25_list.append(NDCG_binary_at_k_batch(pred_val, cold_test_data, k=25))
r50_list.append(Recall_at_k_batch(pred_val, cold_test_data, k=50))
n50_list.append(NDCG_binary_at_k_batch(pred_val, cold_test_data, k=50))
r100_list.append(Recall_at_k_batch(pred_val, cold_test_data, k=100))
n100_list.append(NDCG_binary_at_k_batch(pred_val, cold_test_data, k=100))

# %%
#content similarity with 2nd order regression (B1 to B5, B34)
print("Test Recall@10=%.5f (%.5f)" % (np.nanmean(r10_list), np.nanstd(r10_list) / np.sqrt(len(r10_list))))
# print("Test NDCG@10=%.5f (%.5f)" % (np.nanmean(n10_list), np.nanstd(n10_list) / np.sqrt(len(n10_list))))

print("Test Recall@25=%.5f (%.5f)" % (np.nanmean(r25_list), np.nanstd(r25_list) / np.sqrt(len(r25_list))))
# print("Test NDCG@25=%.5f (%.5f)" % (np.nanmean(n25_list), np.nanstd(n25_list) / np.sqrt(len(n25_list))))

print("Test Recall@50=%.5f (%.5f)" % (np.nanmean(r50_list), np.nanstd(r50_list) / np.sqrt(len(r50_list))))
# print("Test NDCG@50=%.5f (%.5f)" % (np.nanmean(n50_list), np.nanstd(n50_list) / np.sqrt(len(n50_list))))

# print("Test NDCG@100=%.5f (%.5f)" % (np.nanmean(n100_list), np.nanstd(n100_list) / np.sqrt(len(n100_list))))
print("Test Recall@100=%.5f (%.5f)" % (np.nanmean(r100_list), np.nanstd(r100_list) / np.sqrt(len(r100_list))))

# %% [markdown]
# ### Run our method

# %%
X = train_data.toarray()
values = train_data.nonzero()


#initialization
lambda1s = [100,300,500,700,900]
lambda2s = [1,10,50,100]
lambda3s = [1]
ks = [0]

b = np.average(X,0)
xo = np.mean(b)

Xtilde = X1bis+X2bis+X3bis+X4bis+X5bis+X6bis+X7bis+X8bis+X9bis+X10bis+X11bis+X12bis+X13bis+X14bis+X15bis+X16bis

# %%
for k in ks:
    for lambda1 in lambda1s:
        for lambda2 in lambda2s:
            for lambda3 in lambda3s:

                perc_value = 10
                rho = 1 
                yo = lambda1
                y = [lambda1+k*bi-k*xo for bi in b]


                #transform vector to diag matrix IR
                vector = np.sum(X, axis=0)
                percentile = max(np.percentile(vector,perc_value),1)
                k = lambda2/percentile
                vector_tr = np.zeros(len(vector))
                for counter,item in enumerate(vector):
                    if item <= percentile:
                        vector_tr[counter] = k*(percentile-item)

                IR = np.diag(vector_tr)

                #compute P
                P0 = rho*X.T.dot(X)+y*np.diag(np.ones(train_data.shape[1]))+X.T.dot(Xtilde).dot(IR)
                P = np.linalg.inv(P0)
                print("P computed")
                del P0

                #update of Bk
                B_temp = rho*X.T.dot(X)+lambda3*X.T.dot(Xtilde).dot(IR)
                B_tilde = P.dot(B_temp)
                gamma = np.diag(B_tilde) / np.diag(P)
                B_k = B_tilde - P.dot(np.diag(gamma))
                B_k = np.asarray(B_k).reshape((B_k.shape[0],B_k.shape[1]))
                # del B_temp
                # del B_tilde
                # del gamma
                print("B_k updated")

                val_index_min = 0
                n10_list, n20_list, n50_list, n100_list, r10_list, r20_list, r50_list, r100_list = [], [], [], [], [], [], [], []


                pred_val = X.dot(B_k)
                pred_val[values] = -np.inf

                # exclude examples from training and validation (if any)
                n10_list.append(NDCG_binary_at_k_batch(pred_val, cold_vad_data, k=10))
                n20_list.append(NDCG_binary_at_k_batch(pred_val, cold_vad_data, k=25))
                n50_list.append(NDCG_binary_at_k_batch(pred_val, cold_vad_data, k=50))
                n100_list.append(NDCG_binary_at_k_batch(pred_val, cold_vad_data, k=100))
                r10_list.append(Recall_at_k_batch(pred_val, cold_vad_data, k=10))
                r20_list.append(Recall_at_k_batch(pred_val, cold_vad_data, k=25))
                r50_list.append(Recall_at_k_batch(pred_val, cold_vad_data, k=50))
                r100_list.append(Recall_at_k_batch(pred_val, cold_vad_data, k=100))

                n10_list = np.concatenate(n10_list)
                n20_list = np.concatenate(n20_list)
                n50_list = np.concatenate(n50_list)
                n100_list = np.concatenate(n100_list)

                r10_list = np.concatenate(r10_list)
                r20_list = np.concatenate(r20_list)
                r50_list = np.concatenate(r50_list)
                r100_list = np.concatenate(r100_list)

                #0cold-
                print("lambda1={}".format(str(lambda1)))
                print("lambda2={}".format(str(lambda2)))
                print("lambda3={}".format(str(lambda3)))

                print("Test NDCG@10=%.5f (%.5f)" % (np.nanmean(n10_list), np.nanstd(n10_list) / np.sqrt(len(n10_list))))
                print("Test NDCG@25=%.5f (%.5f)" % (np.nanmean(n20_list), np.nanstd(n20_list) / np.sqrt(len(n20_list))))
                print("Test NDCG@50=%.5f (%.5f)" % (np.nanmean(n50_list), np.nanstd(n50_list) / np.sqrt(len(n50_list))))
                print("Test NDCG@100=%.5f (%.5f)" % (np.nanmean(n100_list), np.nanstd(n100_list) / np.sqrt(len(n100_list))))
                print("Test Recall@10=%.5f (%.5f)" % (np.nanmean(r10_list), np.nanstd(r10_list) / np.sqrt(len(r10_list))))
                print("Test Recall@25=%.5f (%.5f)" % (np.nanmean(r20_list), np.nanstd(r20_list) / np.sqrt(len(r20_list))))
                print("Test Recall@50=%.5f (%.5f)" % (np.nanmean(r50_list), np.nanstd(r50_list) / np.sqrt(len(r50_list))))
                print("Test Recall@100=%.5f (%.5f)" % (np.nanmean(r100_list), np.nanstd(r100_list) / np.sqrt(len(r100_list))))
